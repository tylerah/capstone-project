# %%
import boto3
import pandas as pd
import os
import pymysql

from config import ACCESS_ID 
from config import ACCESS_KEY 
from config import db_password

from sqlalchemy import create_engine

# %%
# Retrieving data from S3 bucket and reading it into a dataframe
s3_client = boto3.client(
    "s3",
    aws_access_key_id=ACCESS_ID,
    aws_secret_access_key= ACCESS_KEY)

response = s3_client.get_object(Bucket='group2-yrbs-data', Key='fake_data.csv')

status = response.get("ResponseMetadata", {}).get("HTTPStatusCode")

df = pd.read_csv(response.get("Body"))
df
# Out:
#    This  Is   Fake  Data
# 0     3    1     1     1
# 1     4    2     0     3
# 2     6    8     9     6
# 3     1    9     5     8
# 4     7    4     3     6
# 5     8    2     5     3

# %%
host="yrbs-database2.cfajpmglo7yt.us-west-1.rds.amazonaws.com"
port=int(5432)
user="postgres"
passw=db_password
database="yrbs-database2"

mydb = create_engine("mysql+pymysql://" + user + ":" + passw + "@" + host + ":" + str(port) + "/" + database + "?connect_timeout=10000", echo=False)



df.to_sql(name='fake_data', con=mydb, if_exists = "replace", index=False)


#if dataframe ends up being too big to export, look to module 8.5.1 for more instructions

# Is it making a query?
#
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3255         try:
# -> 3256             return fn()
#    3257         except dialect.dbapi.Error as e:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# ...
